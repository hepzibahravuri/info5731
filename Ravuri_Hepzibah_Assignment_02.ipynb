# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %% [markdown]
# #Scraping IMDB movie reviews

# %%
import requests
from bs4 import BeautifulSoup
import csv
from google.colab import drive


drive.mount('/content/drive')

# Function for scraping
def scrape_reviews(url):
    all_reviews = []
    while len(all_reviews) < 1000:
      user_agent = {'User-agent': 'Mozilla/5.0'}
      # Using requests module
      response = requests.get(url, headers=user_agent)
      soup = BeautifulSoup(response.text, 'html.parser')
      review_containers = soup.find_all("div", class_="review-container")
      if not review_containers:
        print("No review containers found on the page:", url)
        break
      for container in review_containers:
        #getting tags for extraction
        review_text = container.find("div", class_="text").get_text(strip=True)
        rating_element = container.find("span", class_="rating-other-user-rating")
        rating = rating_element.find("span").text if rating_element else None
        reviewer_name = container.find("span", class_="display-name-link").text
        review_date = container.find("span", class_="review-date").text
        all_reviews.append({"Review": review_text, "Rating": rating, "Reviewer": reviewer_name, "Date": review_date})
        if len(all_reviews) >= 1000:
            break
      # load more option search
      load_more_button = soup.find("button", class_="ipl-load-more__button")
      if load_more_button:
        next_page_key = soup.find("div", class_="load-more-data").get("data-key")
        if next_page_key:
            next_page_url = f"{url}?paginationKey={next_page_key}"
            url = next_page_url
        else:
            print("Data-key attribute not found on the Load More button.")
            break
      else:
        break
    return all_reviews

url = "https://www.imdb.com/title/tt9603212/reviews/"

#Function calling
all_reviews = scrape_reviews(url)

# Writing the csv file
csv_file_path = '/content/drive/My Drive/imdb_reviews_dataset.csv'
with open(csv_file_path, mode='w', newline='', encoding="utf-8") as file:
  fieldnames = ['Review', 'Rating', 'Reviewer', 'Date']
  writer = csv.DictWriter(file, fieldnames=fieldnames)
  writer.writeheader()
  for review in all_reviews:
    writer.writerow(review)

print("Reviews have been stored in CSV file:", csv_file_path)
# Out:
# Mounted at /content/drive
# Reviews have been stored in CSV file: /content/drive/My Drive/imdb_reviews_dataset.csv

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.

import pandas as pd
import re

# csv to dataframe using pandas
noiseless_review = pd.read_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv')

def remove_noise(text):
  cleaned_text = re.sub(r'[^\w\s]', '', text)
  return cleaned_text

noiseless_review['Clean_Review'] = noiseless_review['Review'].apply(remove_noise)

noiseless_review.to_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv', index=False)

noiseless_review.head()
# Out:
#                                               Review  Rating         Reviewer  \
# 0  Man.... I wish I loved this movie more than I ...     7.0       Paragon240
# 1  Ethan Hunt has left the mere secret agent stat...     6.0       JackRJosie
# 2  After the first 30 minutes that promised an in...     5.0  ragingbull_2005
# 3  4 considerations for those with high expectati...     5.0           imseeg
# 4  Mission Impossible is one of those rare franch...     5.0      BA_Harrison
#
#            Date                                       Clean_Review
# 0  12 July 2023  Man I wish I loved this movie more than I did ...
# 1  15 July 2023  Ethan Hunt has left the mere secret agent stat...
# 2  18 July 2023  After the first 30 minutes that promised an in...
# 3  12 July 2023  4 considerations for those with high expectati...
# 4  11 July 2023  Mission Impossible is one of those rare franch...

# %%
# Function to remove numbers from the cleaned review text
def remove_numbers(text):
  cleaned_text = re.sub(r'\d+', '', text)
  return cleaned_text

noiseless_review['Clean_Review'] = noiseless_review['Clean_Review'].apply(remove_numbers)

noiseless_review.to_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv', index=False)

noiseless_review.head()
# Out:
#                                               Review  Rating         Reviewer  \
# 0  Man.... I wish I loved this movie more than I ...     7.0       Paragon240
# 1  Ethan Hunt has left the mere secret agent stat...     6.0       JackRJosie
# 2  After the first 30 minutes that promised an in...     5.0  ragingbull_2005
# 3  4 considerations for those with high expectati...     5.0           imseeg
# 4  Mission Impossible is one of those rare franch...     5.0      BA_Harrison
#
#            Date                                       Clean_Review
# 0  12 July 2023  Man I wish I loved this movie more than I did ...
# 1  15 July 2023  Ethan Hunt has left the mere secret agent stat...
# 2  18 July 2023  After the first  minutes that promised an inte...
# 3  12 July 2023   considerations for those with high expectatio...
# 4  11 July 2023  Mission Impossible is one of those rare franch...

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

def remove_stopwords(text):
  words = text.split()
  stopwords_list = set(stopwords.words('english'))
  filtered_words = [word for word in words if word.lower() not in stopwords_list]
  filtered_text = ' '.join(filtered_words)
  return filtered_text

noiseless_review['Clean_Review'] = noiseless_review['Clean_Review'].apply(remove_stopwords)

noiseless_review.to_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv', index=False)

noiseless_review.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               Review  Rating         Reviewer  \
# 0  Man.... I wish I loved this movie more than I ...     7.0       Paragon240
# 1  Ethan Hunt has left the mere secret agent stat...     6.0       JackRJosie
# 2  After the first 30 minutes that promised an in...     5.0  ragingbull_2005
# 3  4 considerations for those with high expectati...     5.0           imseeg
# 4  Mission Impossible is one of those rare franch...     5.0      BA_Harrison
#
#            Date                                       Clean_Review
# 0  12 July 2023  Man wish loved movie Dont get wrong solid acti...
# 1  15 July 2023  Ethan Hunt left mere secret agent status ascen...
# 2  18 July 2023  first minutes promised intellectual action thr...
# 3  12 July 2023  considerations high expectations want avoid se...
# 4  11 July 2023  Mission Impossible one rare franchises getting...

# %%
noiseless_review['Clean_Review'] = noiseless_review['Clean_Review'].str.lower()

noiseless_review.to_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv', index=False)

noiseless_review.head()
# Out:
#                                               Review  Rating         Reviewer  \
# 0  Man.... I wish I loved this movie more than I ...     7.0       Paragon240
# 1  Ethan Hunt has left the mere secret agent stat...     6.0       JackRJosie
# 2  After the first 30 minutes that promised an in...     5.0  ragingbull_2005
# 3  4 considerations for those with high expectati...     5.0           imseeg
# 4  Mission Impossible is one of those rare franch...     5.0      BA_Harrison
#
#            Date                                       Clean_Review
# 0  12 July 2023  man wish loved movie dont get wrong solid acti...
# 1  15 July 2023  ethan hunt left mere secret agent status ascen...
# 2  18 July 2023  first minutes promised intellectual action thr...
# 3  12 July 2023  considerations high expectations want avoid se...
# 4  11 July 2023  mission impossible one rare franchises getting...

# %%
from nltk.stem import PorterStemmer
nltk.download('punkt')

stemmer = PorterStemmer()

def stem_text(text):
  words = nltk.word_tokenize(text)
  stemmed_words = [stemmer.stem(word) for word in words]
  stemmed_text = ' '.join(stemmed_words)
  return stemmed_text

noiseless_review['Clean_Review'] = noiseless_review['Clean_Review'].apply(stem_text)

noiseless_review.to_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv', index=False)

noiseless_review.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               Review  Rating         Reviewer  \
# 0  Man.... I wish I loved this movie more than I ...     7.0       Paragon240
# 1  Ethan Hunt has left the mere secret agent stat...     6.0       JackRJosie
# 2  After the first 30 minutes that promised an in...     5.0  ragingbull_2005
# 3  4 considerations for those with high expectati...     5.0           imseeg
# 4  Mission Impossible is one of those rare franch...     5.0      BA_Harrison
#
#            Date                                       Clean_Review
# 0  12 July 2023  man wish love movi dont get wrong solid action...
# 1  15 July 2023  ethan hunt left mere secret agent statu ascend...
# 2  18 July 2023  first minut promis intellectu action thriller ...
# 3  12 July 2023  consider high expect want avoid sever disappoi...
# 4  11 July 2023  mission imposs one rare franchis get better be...

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text

noiseless_review['Clean_Review'] = noiseless_review['Clean_Review'].apply(lemmatize_text)

noiseless_review.to_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv', index=False)

noiseless_review.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                               Review  Rating         Reviewer  \
# 0  Man.... I wish I loved this movie more than I ...     7.0       Paragon240
# 1  Ethan Hunt has left the mere secret agent stat...     6.0       JackRJosie
# 2  After the first 30 minutes that promised an in...     5.0  ragingbull_2005
# 3  4 considerations for those with high expectati...     5.0           imseeg
# 4  Mission Impossible is one of those rare franch...     5.0      BA_Harrison
#
#            Date                                       Clean_Review
# 0  12 July 2023  man wish love movi dont get wrong solid action...
# 1  15 July 2023  ethan hunt left mere secret agent statu ascend...
# 2  18 July 2023  first minut promis intellectu action thriller ...
# 3  12 July 2023  consider high expect want avoid sever disappoi...
# 4  11 July 2023  mission imposs one rare franchis get better be...

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here
from collections import Counter
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# csv to dataframe
data_analysis = pd.read_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv')

pos = []

def pos_tag_and_count(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    counts = Counter(tag for word, tag in pos_tags)
    return counts

total_counts = data_analysis['Clean_Review'].apply(pos_tag_and_count).apply(Counter).sum()

print("POS Tag Counts:")
print("Nouns (N):", total_counts['NN'] + total_counts['NNS'] + total_counts['NNP'] + total_counts['NNPS'])
print("Verbs (V):", total_counts['VB'] + total_counts['VBD'] + total_counts['VBG'] + total_counts['VBN'] + total_counts['VBP'] + total_counts['VBZ'])
print("Adjectives (Adj):", total_counts['JJ'] + total_counts['JJR'] + total_counts['JJS'])
print("Adverbs (Adv):", total_counts['RB'] + total_counts['RBR'] + total_counts['RBS'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# POS Tag Counts:
# Nouns (N): 88640
# Verbs (V): 20960
# Adjectives (Adj): 33000
# Adverbs (Adv): 8120

# %%
pip install stanfordcorenlp
# Out:
# Collecting stanfordcorenlp
#   Downloading stanfordcorenlp-3.9.1.1-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stanfordcorenlp) (5.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanfordcorenlp) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordcorenlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordcorenlp) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordcorenlp) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanfordcorenlp) (2024.2.2)
# Installing collected packages: stanfordcorenlp
# Successfully installed stanfordcorenlp-3.9.1.1

# %%
import spacy
import pandas as pd

nlp = spacy.load("en_core_web_sm")

def dependency_parsing(review):
    doc = nlp(review)
    for sent in doc.sents:
        print("\nDependency Parsing Tree:")
        for token in sent:
            print(token.text, token.dep_, token.head.text)
        print("\n")

data_analysis['Clean_Review'].apply(dependency_parsing)
# Out:
# Streaming output truncated to the last 5000 lines.
# pocket dobj kept
# mani compound time
# time npadvmod kept
# make xcomp kept
# wonder compound script
# lazi compound script
# script nsubj kill
# kill ccomp make
# old amod gf
# gf dobj kill
# make dep pull
# new amod gf
# gf ccomp make
# also advmod make
# lazi compound mi
# writingunlik compound mi
# mi compound ethan
# ethan nummod plan
# singl amod plan
# smart amod plan
# move compound plan
# plan nsubj felt
# felt ccomp make
# like intj let
# let advcl felt
# go nsubj see
# see ccomp let
# happensam dobj see
# sure advmod gave
# mi compound ignor
# fan compound ignor
# ignor nsubj gave
# weak amod ignor
# gave ccomp see
# film compound rate
# rate dobj gave
#
#
#
# Dependency Parsing Tree:
# instal amod stunt
# franchis det entertain
# wellmad compound highli
# highli nsubj entertain
# entertain nmod stunt
# decent amod fun
# fun dobj entertain
# alway advmod entertain
# tri amod stunt
# invent nmod stunt
# better amod stunt
# stunt nsubj noth
# also advmod noth
# noth ROOT noth
# wrong amod cinemat
# cinemat compound definit
# direct amod excel
# excel compound definit
# definit nmod money
# worth amod money
# money nsubj feel
# still advmod feel
# feel ccomp noth
# like prep feel
# lack pobj like
# someth amod soul
# miss compound soul
# soul appos lack
# moviepartli nsubj think
# think compound harley
# act compound harley
# tom compound harley
# harley nsubj feel
# amaz advmod harley
# everyth compound rest
# rest pobj amaz
# feel ccomp feel
# like prep feel
# partli pobj like
# end parataxis feel
# like prep end
# cherri compound top
# top compound movi
# cliffhang compound movi
# movi nsubj end
# sort advmod end
# end conj feel
# anoth amod thing
# thing nsubj bother
# bother ccomp end
# chase compound scene
# scene compound event
# adrenalin compound induc
# induc compound event
# event dobj bother
# entertain conj noth
#
#
#
# Dependency Parsing Tree:
# ye ROOT ye
#
#
#
# Dependency Parsing Tree:
# oh intj deliv
# boy compound deliv
# deliv nsubj feel
# also advmod feel
# feel ROOT feel
# like prep feel
# purpos pobj like
# almost advmod like
# like prep feel
# watch pobj like
# fastfuri compound crazi
# le compound crazi
# crazi dobj watch
# better compound highli
# actedi compound highli
# highli nsubj recommend
# recommend conj feel
# movi dobj recommend
# like prep recommend
# previou pobj like
# instal amod love
# love appos previou
# one nummod action
# action appos previou
# insan amod time
# good amod time
# time compound howev
# howev compound movi
# movi compound time
# time nsubj end
# end ccomp recommend
# franchis det peopl
# clearli amod peopl
# peopl nsubj involv
# involv compound start
# start nsubj get
# get ccomp end
# bore nmod movi
# good amod movi
# entertain compound movi
# movi nmod soulless
# hollow amod soulless
# soulless nsubj was
# was ccomp get
# nt neg was
# coupl compound scene
# action compound scene
# scene nsubj rememb
# would aux rememb
# rememb conj feel
# singl amod day
# thing compound movi
# movi compound coupl
# coupl compound day
# day dobj rememb
#
#
#
# Dependency Parsing Tree:
# watch ROOT watch
# greatest amod cinema
# carchas compound cinema
# histori compound cinema
# cinema dobj watch
# still advmod was
# was ccomp watch
# nt neg was
# even advmod best
# best advmod was
# scene compound fantast
# movieaft compound fantast
# fantast nsubj underwat
# underwat ccomp was
# open amod introduct
# introduct nmod film
# next amod film
# imposs amod mission
# mission compound film
# rest compound film
# film nsubj essenti
# essenti ccomp underwat
# huge amod setpiec
# action compound setpiec
# setpiec nsubj get
# like prep setpiec
# noth pobj like
# ever advmod noth
# experienc compound screen
# screen appos noth
# beforeeveryth advmod get
# get ccomp essenti
# exponenti amod pas
# epic amod time
# time compound pas
# pas nsubj think
# think ccomp get
# sure amod el
# peak compound el
# someth compound el
# el nsubj come
# come compound crash
# crash nsubj go
# onto prep crash
# screen compound stake
# stake compound rise
# rise pobj onto
# even advmod higher
# higher advmod rise
# go ccomp think
# againth amod pace
# pace nsubj quit
# quit ccomp go
# uniqu dobj quit
# feel advcl go
# like mark work
# sequenc compound shortfilm
# thrill compound shortfilm
# shortfilm nsubj work
# still advmod work
# work advcl feel
# whole amod moment
# narr amod momentum
# awesom compound momentum
# momentum compound pul
# pul nmod moment
# everi amod moment
# moment dobj work
# ca aux imagin
# nt neg imagin
# imagin advcl work
# top amod part
# part dobj imagin
# can aux wait
# not neg wait
# wait ccomp watch
# find xcomp wait
# outep compound movement
# movement compound stunt
# ambit compound stunt
# stunt nmod humour
# humour nmod bravado
# brilliant amod bravado
# new amod charact
# charact nmod bravado
# sheer amod bravado
# bravado dobj find
# behind prep bravado
# camera pobj behind
# ever advmod find
# film nmod moment
# practic amod pandem
# pandem appos film
# obvious amod screen
# watch npadvmod biggest
# biggest amod screen
# cinema compound screen
# screen appos film
# possibl compound moment
# moment compound train
# train nsubj enter
# enter nsubj say
# tunnel compound liter
# liter compound fault
# breathtakingif compound fault
# look compound fault
# fault dobj enter
# would aux say
# say ccomp find
# exposit compound scene
# scene compound bit
# drag compound bit
# bit nsubj felt
# almost advmod felt
# felt ccomp say
# like prep felt
# repeat pobj like
# even advmod complain
# ca aux complain
# nt neg complain
# complain advcl felt
# stylishli amod film
# film dobj complain
# ever advmod franchisejust
# franchisejust npadvmod let
# let ccomp watch
# cruis amod mcquarri
# mcquarri nsubj produc
# produc compound film
# everi amod film
# action compound film
# film nsubj made
# made ccomp let
# nobodi compound level
# el compound level
# remot compound level
# close amod level
# level nsubj watch
# would aux watch
# gladli nsubj watch
# watch ccomp made
# immedi compound book
# book compound ticket
# ticket compound right
# right dobj watch
#
#
#
# Dependency Parsing Tree:
# want ROOT want
# write compound larh
# larh compound review
# review nsubj make
# make ccomp want
# mani compound detail
# detail nsubj thought
# thought ccomp make
# aw intj nopelet
# movi compound deserv
# deserv npadvmod aw
# nopelet nmod word
# short amod fulfil
# fulfil compound amount
# amount compound word
# word nsubj say
# say ccomp thought
# main amod gist
# gist nsubj want
# want ccomp say
# humor compound movi
# movi dobj want
#
#
#
# Dependency Parsing Tree:
# aw det repetit
# repetit nsubj saw
# saw ROOT saw
# previou compound part
# part nsubj bother
# bother ccomp saw
# depth amod charact
# charact compound demis
# onedimension compound demis
# shallow amod hero
# sympathi compound hero
# hero compound demis
# demis nsubj make
# make ccomp saw
# u compound vapid
# vapid nsubj indiffer
# indiffer ccomp make
# plot compound control
# whole amod idea
# idea compound control
# joke compound control
# control dobj indiffer
# even advmod first
# first amod cruis
# part nmod sen
# drag nmod sen
# forev amod sen
# sen nmod part
# part nmod cruis
# huge amod cruis
# wast compound timetom
# timetom amod cruis
# cruis nsubj stop
# must aux stop
# stop ccomp make
# ever advmod stop
# piti dep stop
# part nsubj make
# make ccomp piti
# whole amod couldv
# franchis det couldv
# sour amod couldv
# spoil compound dissapoint
# dissapoint compound couldv
# couldv ccomp make
# great amod couldv
# nopebland cc stop
# silli conj saw
#
#
#
# Dependency Parsing Tree:
# straight advmod dead
# dead nsubj reckon
# reckon nsubj think
# part compound fine
# fine nsubj think
# think ROOT think
# weakest advmod put
# last amod instalmentsi
# four nummod instalmentsi
# instalmentsi nsubj put
# ca aux put
# nt neg put
# put ccomp think
# finger dative put
# one nummod thing
# exact amod thing
# thing nsubj felt
# felt conj think
# littl compound compar
# underdon compound compar
# compar dobj felt
# last amod mi
# mi npadvmod expect
# expect advcl felt
# big amod thing
# thing nmod movi
# whole amod movi
# movi nsubj felt
# combin compound thing
# thing nsubj felt
# like prep thing
# act pobj like
# felt ccomp expect
# littl compound script
# weak amod script
# guess compound script
# script nmod action
# fine amod action
# action dobj felt
# decent amod compar
# great amod compar
# compar appos action
#
#
#
# Dependency Parsing Tree:
# mi dep use
# like prep use
# john compound wick
# wick pobj like
# i nsubj use
# m aux use
# use nsubj especi
# plot compound noth
# noth compound alway
# new compound alway
# alway dobj use
# still advmod interest
# interest ccomp use
# especi nsubj got
# time dobj especi
# real amod advanc
# world compound advanc
# advanc nsubj seem
# seem advcl especi
# heat nmod pickpocket
# whole amod pickpocket
# pickpocket nmod hour
# key amod hour
# hour nsubj especi
# also advmod got
# got ROOT got
# bore advmod fast
# fast amod clich
# mani compound clich
# clich nsubj start
# start compound combat
# pile compound hand
# hand compound hand
# hand compound combat
# combat compound stuff
# weakest amod stuff
# stuff dobj got
# i nsubj seen
# ve aux seen
# seen relcl stuff
# especi ccomp seen
# venic amod scene
# bridg compound scene
# scene dobj especi
# look conj got
# aw intj look
# like intj see
# could aux see
# see advcl look
# choreographi amod storm
# best amod storm
# scene compound storm
# desert compound storm
# storm nsubj start
# start ccomp see
# realli compound attent
# attent dobj start
# everyth nsubj seem
# seem conj got
# averagei nsubj know
# do aux know
# nt neg know
# know ccomp seem
# everyon compound someon
# el compound someon
# complet compound trick
# trick compound someon
# someon nsubj go
# go ccomp know
# someon compound mask
# el compound mask
# mask compound stage
# bore compound stage
# stage dobj go
#
#
#
# Dependency Parsing Tree:
# i nsubj mean
# m appos i
# kinda advmod roll
# roll compound hope
# eye compound realli
# realli compound hope
# hope compound fuse
# machin compound fuse
# blow compound fuse
# fuse appos i
# mean nsubj seen
# seen ccomp see
# last amod stunt
# themtom amod cruis
# cruis compound stunt
# awesom compound stunt
# stunt compound wish
# alway amod respect
# respect compound thing
# thing compound wish
# realli compound wish
# wish nsubj show
# did aux show
# nt neg show
# show ccomp seen
# motorbik compound cliff
# cliff compound jump
# jump compound trailer
# scene compound trailer
# trailer nsubj see
# see compound stunt
# trailer compound liter
# liter nmod stunt
# whole amod stunt
# stunt nsubj get
# do aux get
# nt neg get
# get ccomp show
# wrong amod impress
# truli compound impress
# impress nsubj show
# show ccomp seen
# whole amod complet
# thing compound complet
# complet nsubj kill
# kill ccomp show
# meim compound bum
# slightli compound bum
# bum dobj kill
# one nsubj come
# come aux see
# see ROOT see
# indian amod watch
# jone compound lot
# lot compound watch
# fun compound watch
# watch nsubj care
# do aux care
# nt neg care
# care ccomp see
# runtim amod suck
# suck dobj care
# whole amod time
# time npadvmod care
# felt ccomp see
# timepeopl compound movi
# love compound movi
# movi compound mi
# mi nsubj fizzl
# may aux fizzl
# fizzl ccomp felt
# bit dobj fizzl
# one npadvmod fizzl
#
#
#
# Dependency Parsing Tree:
# mission compound imposs
# imposs nsubj reckon
# dead amod imposs
# reckon ROOT reckon
# part dobj reckon
# mi nsubj anoth
# anoth ccomp reckon
# strong amod cruis
# entri amod cruis
# actionspi nmod cruis
# seri compound cruis
# ethan compound cruis
# cruis nsubj look
# look conj reckon
# slightli amod determin
# older amod determin
# le compound determin
# determin attr look
# save conj reckon
# world compound film
# believ compound film
# sequel compound film
# film dobj save
# last amod outing
# outing nsubj see
# well advmod see
# see conj reckon
# time dobj see
# there expl skynetlik
# skynetlik ccomp see
# sentientai dobj skynetlik
# that mark get
# manipul compound nefari
# nefari compound type
# type compound take
# take compound team
# world compound team
# imf compound team
# team nsubj get
# get ccomp skynetlik
# two nummod halv
# halv compound luther
# key amod stop
# stop nmod ferguson
# itisla amod ferguson
# ferguson compound luther
# benji compound luther
# pegg compound luther
# luther nsubj rhame
# rhame conj reckon
# back advmod rhame
#
#
#
# Dependency Parsing Tree:
# well advmod keep
# cia compound bos
# bos compound kittridg
# kittridg compound czerni
# czerni compound thief
# grace compound atwel
# atwel compound thief
# thief compound guy
# newcom nmod guy
# bad amod guy
# guy nsubj keep
# keep ROOT keep
# thwart compound gabriel
# gabriel oprd keep
# moral amod ethan
# ethan npadvmod keep
# past oprd keep
# pari compound mcquarri
# klementieff compound consist
# consist compound mcquarri
# mcquarri compound director
# director pobj past
# two nummod film
# previou compound film
# film appos director
# help oprd keep
# everyth nsubj feel
# feel ccomp help
# assur compound realli
# work compound realli
# realli dobj feel
# solid amod falloutther
# followup compound falloutther
# falloutther nsubj run
# funni compound moment
# moment compound sincer
# sincer appos falloutther
# one nummod ethan
# ethan appos falloutther
# run conj keep
# contractuallyoblig nmod train
# whole amod train
# final amod train
# scene compound train
# train dobj run
# excel oprd keep
# mani compound thing
# thing nsubj happen
# happen ccomp excel
# there advmod happen
# plenti advcl happen
# good amod setpiec
# setpiec dobj plenti
# throughout prep setpiec
# includ amod chase
# good amod chase
# car compound chase
# chase compound piecederesist
# howev compound piecederesist
# piecederesist compound jump
# motorbik compound base
# cliff compound base
# base compound jump
# jump pobj throughout
# someth nmod fact
# el compound fact
# fact appos jump
# cruis compound inspir
# real amod multipl
# multipl compound inspir
# time compound inspir
# crazi compound inspir
# inspir oprd keep
#
#
#
# Dependency Parsing Tree:
# man nsubj wish
# wish ROOT wish
# love compound movi
# movi nsubj get
# do aux get
# nt neg get
# get ccomp wish
# wrong amod stunt
# solid amod movi
# action compound movi
# movi compound stunt
# jawdrop compound stunt
# stunt dobj get
# best amod movi
# seri amod movi
# mission compound imposs
# imposs compound movi
# movi nsubj felt
# felt conj wish
# like prep felt
# small amod step
# step pobj like
# backward advmod step
# franchis det work
# fallout npadvmod mindblow
# mindblow amod action
# action compound work
# sequenc compound stunt
# stunt compound work
# work dobj felt
# along prep work
# develop xcomp felt
# ethan compound relationship
# relationship dobj develop
# ilsa compound ethan
# provid compound closur
# closur compound show
# julia compound show
# show compound length
# length compound ethan
# ethan nsubj go
# would aux go
# go ccomp felt
# protect advcl go
# closest amod villain
# battl compound impos
# impos compound villain
# villain nsubj reckon
# dead nsubj reckon
# reckon ccomp protect
# part nsubj stretch
# one nummod part
# stretch ccomp reckon
# movi dobj stretch
# across mark develop
# two nummod showcas
# film nmod showcas
# seemingli compound showcas
# showcas nmod charact
# action compound spectacl
# spectacl appos showcas
# action compound charact
# spectacl compound sacrif
# sacrif compound charact
# charact nsubj develop
# develop advcl reckon
# charact nmod love
# grown amod love
# love compound film
# decad compound film
# film nsubj felt
# felt conj wish
# sidelin compound ignor
# ignor compound hayley
# wast compound hayley
# hayley nsubj atwel
# atwel ccomp felt
# new amod chew
# charact compound chew
# chew compound time
# screen compound time
# time compound fantast
# fantast nsubj want
# want ccomp atwel
# see xcomp want
# origin compound team
# team compound abil
# new amod abil
# villain compound inconsist
# inconsist compound abil
# abil dobj see
# confus npadvmod see
# intimid compound emot
# import compound emot
# emot compound moment
# moment nsubj feel
# did aux feel
# nt neg feel
# feel conj wish
# weight compound definit
# definit compound part
# part nsubj tie
# two nsubj tie
# might aux tie
# tie ccomp feel
# everyth compound togeth
# togeth dobj tie
# make advcl wish
# enjoy nsubj retrospect
# part dobj enjoy
# one nummod part
# retrospect amod left
# unfortun amod left
# left nsubj want
# want ccomp make
# one dobj want
#
#
#
# Dependency Parsing Tree:
# ethan compound hunt
# hunt nsubj left
# left ROOT left
# mere amod statu
# secret amod agent
# agent compound statu
# statu dobj left
# ascend conj left
# live amod messiahther
# perfect amod messiahther
# messiahther dobj ascend
# much advmod wrong
# wrong amod movi
# movi appos messiahther
# serious amod pain
# pain compound convolut
# serious amod love
# love compound movi
# seri amod movi
# mission compound imposs
# imposs compound movi
# movi compound steadili
# steadili compound convolut
# becom compound convolut
# convolut compound stupidli
# stupidli nsubj written
# written ccomp ascend
# film npadvmod written
# reach dep written
# peak npadvmod absurd
# absurd amod feel
# feel dobj ascend
# like mark pull
# top amod trick
# fast amod furiou
# furiou compound movi
# movi nmod action
# foolish amod action
# action nmod trick
# cheap amod trick
# parlor compound trick
# trick nsubj pull
# pull advcl feel
# heart compound string
# string dobj pull
# empti compound relationship
# relationship compound horribl
# horribl appos string
# write conj pull
# poor amod plot
# plot compound developmenti
# developmenti dobj write
# mean npadvmod happen
# serious nsubj happen
# ever advmod happen
# happen compound show
# show dobj write
# do aux tell
# nt neg tell
# tell advcl left
# becom dobj tell
# rather advmod ridiculousconvolut
# ridiculousconvolut ccomp tell
# villain dobj ridiculousconvolut
# dialogu advmod ridiculousconvolut
# your poss plan
# tell compound plan
# plan nsubj establish
# establish ccomp dialogu
# new amod order
# world compound order
# order dobj establish
# get advcl ridiculousconvolut
# key amod stop
# someon compound stop
# stop nsubj badha
# would aux badha
# badha ccomp get
# ethan compound hunt
# hunt compound suddenli
# suddenli compound natur
# becom compound vanilla
# vanilla compound bond
# jame compound bond
# bond compound bond
# bond compound girl
# girl compound lazi
# cycl compound everi
# everi compound lazi
# film compound lazi
# lazi nsubj write
# write relcl suddenli
# natur nsubj feel
# feel ccomp badha
# forc nmod pain
# blighit amod pain
# pain nsubj give
# give ccomp feel
# lowth compound truth
# truth compound movi
# movi dative give
# mindless compound action
# entertain compound action
# action appos movi
# tom compound cruis
# cruis compound stunt
# deliv compound stunt
# awesom compound stunt
# stunt compound authent
# seldom advmod compar
# compar compound mi
# mi compound authent
# film compound authent
# horribl compound authent
# fun compound entertain
# entertain compound scour
# scour compound opinion
# opinion compound authent
# reput compound authent
# authent nsubj feel
# feel ccomp get
# mission compound imposs
# imposs nsubj seri
# seri dobj tell
#
#
#
# Dependency Parsing Tree:
# first compound promis
# minut compound promis
# promis compound film
# intellectu amod action
# action compound film
# thriller compound film
# film nsubj start
# start nsubj petti
# nosed amod thief
# mediocr nmod thief
# introduc amod thief
# thief dobj start
# constantli compound disloyalti
# indulg compound disloyalti
# disloyalti compound petti
# petti nsubj held
# gain dobj petti
# toward prep gain
# imf compound hunt
# hunt nsubj held
# held ROOT held
# high amod life
# regard compound hunt
# hunt compound life
# life nsubj understand
# could aux understand
# nt neg understand
# understand ccomp held
# film dobj understand
# also advmod bother
# does aux bother
# nt neg bother
# bother conj held
# itneith compound concern
# concern dobj bother
# call xcomp bother
# action dobj call
# set advcl bother
# piec dobj set
# _ nmod fallout
# fallout npadvmod set
# _ punct held
#
#
#
# Dependency Parsing Tree:
# plethora nsubj tie
# one nummod tie
# tie compound togeth
# togeth compound hype
# cogent compound stori
# stori compound hype
# line compound hype
# hype compound time
# run compound time
# time npadvmod make
# close amod view
# minut compound test
# test compound view
# patienceread amod critic
# critic compound post
# review compound post
# post compound view
# view nsubj make
# make ROOT make
# feel ccomp make
# written acomp feel
# entiti ccomp make
# ai ccomp make
# behemoth compound center
# center compound entertain
# perceiv compound entertain
# entertain compound valu
# valu compound impli
# impli nsubj remot
# even advmod remot
# remot advcl make
# connect compound wonder
# realityit compound wonder
# wonder dobj remot
# falter compound u
# u nsubj offic
# box npadvmod offic
# offic nmod crowd
# top amod crowd
# gun compound crowd
# maverick compound crowd
# crowd nsubj go
# go ccomp make
# turn advcl go
# especi oprd turn
# outsid compound u
# u compound power
# cruis compound star
# star compound power
# power dobj especi
# do aux believ
# nt neg believ
# believ compound themdisappoint
# plea compound themdisappoint
# themdisappoint npadvmod make
#
#
#
# Dependency Parsing Tree:
# consider ROOT consider
# high nsubj expect
# expect ccomp consider
# want nsubj avoid
# avoid ccomp expect
# sever amod disappoint
# disappoint dobj avoid
# new amod actor
# actor compound lack
# lack compound realli
# charismai amod realli
# need compound viciou
# viciou nmod realli
# bad amod guy
# guy compound realli
# realli nsubj pull
# pull advcl avoid
# thrill compound movii
# movii dobj pull
# none nsubj is
# is ccomp expect
# nt neg is
# even advmod one
# one nummod girl
# bad amod supposedli
# guy nmod numer
# particular amod numer
# numer compound supposedli
# supposedli compound bad
# bad amod girl
# guy compound girl
# girl nsubj fail
# fail ccomp is
# impress compound tea
# mehaley compound atwel
# atwel compound cup
# cup compound tea
# tea dobj fail
# either preconj unfortun
# unfortun amod screentim
# get compound screentim
# lot compound screentim
# screentim nmod movi
# last amod longther
# longther compound way
# way npadvmod much
# much amod explanatori
# superflu compound explanatori
# explanatori advmod screentim
# talk compound realli
# realli nmod movi
# slow amod movi
# movi dobj expect
# last amod way
# way npadvmod expect
# long amod hour
# hour compound minut
# minut npadvmod way
# half amod hour
# hour npadvmod expect
# could aux cut
# easili nsubj cut
# cut ccomp expect
# iti dobj cut
# start dobj cut
# look aux watch
# watch dep cut
# halfway compound throughand
# throughand nsubj got
# got conj consider
# bore nsubj said
# said ccomp consider
# say intj got
# got ccomp said
# blip compound bore
# bore dobj got
# that mark want
# last amod thing
# thing nsubj want
# want ccomp got
# experi amod stunt
# action compound movi
# movi compound stunt
# stunt nsubj look
# do aux look
# nt neg look
# look ccomp want
# realther compound ad
# heavi compound ad
# layer compound ad
# ad nmod effect
# cgi nsubj effect
# effect dobj look
# real amod stunt
# stunt nmod stop
# actual amod stop
# stop dobj effect
# look advcl look
# real amod way
# real amod stunt
# stunt compound look
# look compound way
# way npadvmod impress
# impress advmod look
# behind prep impress
# scene compound footag
# footag compound joke
# actual amod movi
# movi compound joke
# joke nsubj fall
# fall conj look
# flatsimon compound look
# pegg compound look
# look dobj fall
# like prep look
# realli nmod man
# old amod man
# man nsubj lost
# somehow advmod lost
# lost conj consider
# usual amod charm
# wit compound charm
# charm dobj lost
# delight npadvmod lost
# earlier amod movi
# mi amod movi
# movi dobj lost
# without prep lost
# witti compound pegg
# simon compound pegg
# pegg nsubj gone
# gone pcomp without
# joke pobj without
# well advmod lost
# did aux laugh
# nt neg laugh
# laugh conj lost
# loud amod timesthi
# smirk compound timesthi
# timesthi compound movi
# mi compound movi
# movi compound definit
# definit dobj laugh
# one nummod edit
# worst amod edit
# edit nmod bore
# worst amod bore
# bore npadvmod definit
# heck aux happen
# never neg happen
# happen advcl laugh
# watch compound conclus
# mi compound moviedespit
# moviedespit nsubj disappoint
# disappoint compound conclus
# conclus nsubj wan
# still advmod wan
# wan ccomp consider
# na advmod thank
# thank advcl wan
# read dep wan
# th compound review
# review compound imdb
# imdb dobj read
#
#
#
# Dependency Parsing Tree:
# mission compound imposs
# imposs dep get
# one nummod rare
# rare dobj imposs
# franchis nsubj get
# get ROOT get
# better advmod better
# better amod word
# instal amod word
# nowth compound sum
# plot compound sum
# sum compound word
# word compound hunt
# ethan compound hunt
# hunt nsubj find
# must aux find
# find ccomp get
# special amod human
# key amod human
# save compound human
# human dobj find
# ai compound entiti
# entiti nsubj make
# yet advmod entiti
# writer conj entiti
# make ccomp find
# matter ccomp make
# unnecessarili compound convolut
# convolut compound wind
# film compound wind
# wind dobj matter
# incred amod hour
# hour compound minut
# minut npadvmod get
# long amod larg
# larg compound percentag
# percentag compound chase
# far advmod whiteknuckl
# whiteknuckl compound issueson
# action compound issueson
# lead compound issueson
# seriou compound pace
# pace compound issueson
# issueson compound film
# film compound chase
# key amod chase
# setpiec compound car
# car compound chase
# chase npadvmod get
# ethan nummod chase
# newest amod play
# imf nmod hayley
# member compound hayley
# grace compound hayley
# hayley nmod careen
# atwel compound careen
# careen amod play
# yellow amod play
# fiat compound play
# play nsubj laugh
# laugh ccomp get
# odd amod tone
# gener compound tone
# tone dobj laugh
#
#
#
# Dependency Parsing Tree:
# franchis compound moor
# roger compound moor
# moor compound abl
# abl nsubj make
# make ccomp see
# kind compound nonsens
# nonsens nsubj work
# work compound dead
# eye compound cv
# silli nmod cv
# yellow amod cv
# car compound cv
# cv compound dead
# dead nsubj reckon
# reckon ccomp make
# embarrassingth compound bomb
# deactiv compound bomb
# bomb compound pad
# benji compound pad
# simon compound pad
# pegg compound pointless
# pointless compound pad
# piec compound pad
# pad nsubj easili
# must aux easili
# solv amod sever
# sever amod order
# wellknown compound riddl
# riddl compound order
# order dep easili
# second amod piec
# spare amod end
# end nmod piec
# final amod piec
# piec compound puzzl
# puzzl nsubj easili
# could aux easili
# easili ccomp reckon
# solv amod rotat
# simpli compound rotat
# rotat dobj easili
# last amod dial
# dial npadvmod easili
# remain ccomp make
# option nsubj occur
# does aux occur
# nt neg occur
# occur ccomp make
# brainiac npadvmod occur
# benji npadvmod entir
# entir amod scene
# scene nsubj cut
# could aux cut
# cut ccomp make
# film dobj cut
# without prep cut
# detrimentcruis amod cliff
# muchtout compound motorcycl
# motorcycl compound cliff
# jump compound cliff
# cliff pobj without
# see ROOT see
# ethan nummod speed
# ride nmod bike
# bike nmod speed
# high amod speed
# speed nmod terrain
# rough amod terrain
# rocki compound terrain
# terrain dobj see
# toward prep terrain
# precipic pobj toward
# i nsubj m
# m nsubj hit
# expert acomp m
# would aux hit
# nt neg hit
# hit ccomp see
# extrem amod pelt
# uneven amod realiti
# ground compound crash
# speed compound crash
# caus compound crash
# crash compound realiti
# realiti dobj extrem
# cruis compound pelt
# pelt dobj hit
# along prep hit
# special amod construct
# construct pobj along
#
#
#
# Dependency Parsing Tree:
# smooth amod ramp
# ramp compound rocki
# rocki nsubj ground
# ground nsubj tote
# ad compound digit
# digit dobj ground
# postin nmod ridicul
# one nummod postin
# ridicul compound hunt
# scene compound hunt
# hunt compound rescu
# rescu compound grace
# grace compound parachut
# parachut compound side
# side nsubj move
# move conj ground
# train compound carriag
# carriag nsubj built
# built conj ground
# balsa amod wood
# wood dobj built
# right compound gun
# gun npadvmod ground
# tote ROOT tote
# henchman nsubj chanc
# chanc ccomp tote
# equal amod fall
# unlik nmod guy
# bad amod guy
# guy compound locomot
# gabriel compound locomot
# esai nmod locomot
# moral amod locomot
# depart compound speed
# speed compound locomot
# locomot compound fall
# fall compound train
# backward amod train
# train dobj chanc
# onto prep train
# crash compound mat
# mat pobj onto
# wait compound realist
# truck compound feat
# feat compound realist
# realist nsubj chanc
# would aux chanc
# le advmod chanc
# chanc conj tote
# success nsubj ask
# ask ccomp chanc
# hayley compound atwel
# atwel compound dateand
# dateand compound screen
# graphic amod design
# design compound hate
# hate compound fact
# fact compound crime
# grace compound variou
# variou compound crime
# crime compound screen
# flash compound screen
# laptop compound screen
# screen compound misdemeanour
# misdemeanour nsubj differ
# differ amod size
# font compound point
# point compound size
# size nsubj thing
# would aux thing
# thing ccomp ask
# bore dobj thing
# programm amod typographyprev
# interest compound typographyprev
# typographyprev compound film
# film compound actress
# total amod actress
# disast nmod turn
# great amod turn
# turn compound actress
# pom compound klementieff
# klementieff compound actress
# blond compound henchwoman
# henchwoman compound actress
# pari compound actress
# actress nsubj steal
# steal ccomp tote
# everi amod despit
# scene compound despit
# despit dobj steal
# next prep steal
# dialogu amod grace
# incred amod grace
# final amod ethan
# ethan compound grace
# grace dobj steal
# must aux race
# race ccomp tote
# sever xcomp race
# train compound carriag
# carriag compound director
# dangl amod director
# edg compound director
# bridg compound director
# director compound mcquarri
# christoph compound mcquarri
# mcquarri nsubj remind
# remind ccomp tote
# u compound littl
# littl dobj remind
# late advmod put
# put conj tote
# togeth advmod put
# effect compound scene
# action compound scene
# scene dobj put
#
#
#
# Dependency Parsing Tree:
# saw ROOT saw
# one nummod boy
# theatr amod boy
# boy nmod rush
# adrenalin appos boy
# rush dobj saw
# latest amod imposs
# mission compound imposs
# imposs dobj rush
# featur amod stunt
# incred amod stunt
# stunt nsubj put
# ever advmod put
# put ccomp saw
# camera compound stori
# stori dobj put
# absolut ccomp put
# exhilar amod continu
# continu nsubj bring
# bring ccomp absolut
# new amod movi
# life compound veteran
# veteran compound movi
# movi dobj bring
# franchis det movi
# sheer amod scale
# scale compound movi
# movi nsubj help
# epic amod twist
# everi compound twist
# twist compound turn
# turn compound movi
# movi appos movi
# can aux help
# not neg help
# help conj put
# marvel xcomp help
# incred amod use
# set amod use
# use dobj marvel
# bring xcomp help
# movi compound movi
# life compound movi
# movi dobj bring
# beg nsubj seen
# seen ccomp saw
# biggest amod screen
# screen compound truli
# possibl compound truli
# truli nsubj feel
# feel ccomp seen
# grandeur amod film
# film compound cruis
# tom compound cruis
# cruis compound deliv
# deliv ccomp feel
# one nummod year
# best amod year
# movi compound year
# year npadvmod deliv
# can aux recommend
# not neg recommend
# recommend ccomp saw
# see xcomp recommend
# enough advmod see
#
#
#
# Dependency Parsing Tree:
# basic amod movi
# movi nmod attempt
# big amod stupiddefinit
# loud amod stupiddefinit
# stupiddefinit nmod attempt
# loud amod attempt
# fact compound music
# music compound attempt
# attempt nsubj turn
# turn ROOT turn
# even advmod minor
# minor amod scene
# scene nsubj heartpound
# sort aux heartpound
# heartpound ccomp turn
# climaxther amod ridicul
# endless amod ridicul
# ridicul compound fight
# fight compound cruis
# tom compound cruis
# cruis nsubj predict
# predict ccomp heartpound
# unstopp compound matter
# matter dobj predict
# mani compound oppon
# oppon dobj predict
#
#
#
# Dependency Parsing Tree:
# he compound girl
# slim amod girl
# girl nsubj get
# get ROOT get
# beat amod refreshingli
# multipl compound men
# men nmod blunt
# emili nmod blunt
# blunt compound refreshingli
# right amod comment
# comment compound fight
# fight compound refreshingli
# sicario compound refreshingli
# refreshingli nsubj lose
# lose ccomp get
# bigger amod guy
# guy dobj lose
# note ccomp lose
# hollywood compound fight
# fight compound pound
# scene compound pound
# pound compound woman
# woman nsubj whip
# whip ccomp note
# larger amod tepid
# male amod tepid
# cheesyth nmod tepid
# dull amod tepid
# tepid compound fighter
# waytoopretti compound implaus
# villain compound implaus
# implaus compound fighter
# formid compound fighter
# fighter dobj whip
# sure advmod look
# does aux look
# nt neg look
# look conj get
# like prep look
# one nummod movi
# action compound movi
# movi nmod guy
# good amod guy
# villain amod guy
# evil amod guy
# guy nsubj look
# look dep look
# like prep look
# french amod train
# fashion compound mogulh
# mogulh compound train
# cruis compound fight
# fight compound train
# top compound train
# wait compound train
# move compound train
# train pobj like
# have aux seen
# nt neg seen
# seen conj get
# ridicul compound time
# sort compound thing
# thing compound time
# hundr compound time
# time nsubj keep
# beforeth amod plot
# tedious amod plot
# overcompl compound plot
# plot nsubj make
# make relcl time
# hard advmod make
# keep nmod scene
# track dobj keep
# who nsubj side
# side relcl keep
# care compound appar
# appar nmod suppos
# usual amod suppos
# day compound suppos
# suppos dobj side
# root xcomp keep
# u dobj root
# governmentin compound scene
# scene nsubj involv
# involv ccomp seen
# convers dative involv
# virtual amod line
# everi amod line
# line compound charact
# mere amod plot
# plot compound charact
# exposit compound charact
# charact nsubj tell
# tell conj get
# u dobj tell
# stilt xcomp tell
# dialogu advmod tell
# what nsubj go
# go advcl jump
# what det suppos
# suppos nsubj happen
# happen ccomp go
# suppos compound parachut
# feelth compound parachut
# muchtout compound parachut
# parachut nsubj jump
# jump ccomp tell
# actual amod disappoint
# disappoint nsubj quit
# quit conj get
# fast amod youv
# main amod youv
# sourc compound youv
# interest compound youv
# youv dobj quit
# seen acl youv
# promot compound know
# video compound know
# know compound cruis
# cruis nsubj made
# actual advmod made
# made ccomp quit
# jumpth amod truli
# truli nsubj enjoy
# enjoy nsubj sequenc
# sequenc nsubj come
# cleverli advmod sequenc
# workedout amod attempt
# rescu compound attempt
# attempt compound fall
# fall compound come
# train compound come
# come nsubj end
# end ccomp made
# nearli oprd end
#
#
#
# Dependency Parsing Tree:
# two nummod half
# half nummod hour
# hour npadvmod empti
# empti amod nonsenseinclud
# cartoonish amod nonsenseinclud
# nonsenseinclud nsubj cours
# cours ROOT cours
# overlong amod chase
# cartoonish amod chase
# car compound chase
# chase compound movi
# obligatori nmod movi
# dumb amod movi
# summer compound movi
# movi dobj cours
#
#
#
# Dependency Parsing Tree:
# mission compound imposs
# imposs nsubj reckon
# dead amod imposs
# reckon ROOT reckon
# part nsubj confirm
# one nummod part
# confirm ccomp reckon
# mission compound imposs
# imposs dobj confirm
# best advmod confirm
# franchis det current
# current nsubj go
# go compound possibl
# possibl nsubj made
# ever advmod made
# made advcl reckon
# hour compound minut
# minut compound rush
# adrenalin compound rush
# rush nsubj contain
# contain ccomp made
# best amod sequenc
# action compound sequenc
# sequenc nsubj put
# put conj reckon
# film nmod embarrass
# embarrass compound part
# major amod stage
# competit amod set
# set compound stage
# stage compound magnific
# magnific compound part
# part dobj put
# whilst prep put
# still advmod satisfi
# satisfi amod film
# adventur compound possibl
# rightthi compound possibl
# possibl nmod film
# open amod obviou
# obviou compound mission
# mission compound film
# film nsubj need
# deeper advmod mean
# mean amod film
# cinema compound aspect
# aspect compound dissect
# cruis compound dissect
# career compound dissect
# dissect compound time
# time compound film
# film compound woman
# focus compound ethan
# ethan compound woman
# relationship compound woman
# woman appos film
# basic amod declar
# outright amod declar
# declar appos film
# ai nmod element
# soulless amod monster
# monster nmod element
# human amod element
# element appos film
# alway advmod need
# need conj reckon
# perfect amod writer
# film compound releas
# releas compound writer
# writer compound striketom
# striketom dobj need
# cruis compound ethan
# perfect compound ethan
# ethan compound hunt
# hunt nmod time
# strongest advmod hunt
# aspect compound time
# time appos striketom
# round compound explor
# film compound explor
# explor nsubj made
# made conj reckon
# ethan nsubj remind
# remind compound team
# genuin compound care
# care compound team
# team nsubj come
# come ccomp made
# cost compound madman
# physic compound madman
# madman nsubj go
# still advmod go
# go conj reckon
# strong amod fashionv
# stunt compound drive
# drive compound bike
# bike compound fashionv
# cliff compound fashionv
# truli compound fashionv
# breathtak compound fashionv
# fashionv dobj go
# rhame compound ferguson
# simon compound ferguson
# pegg compound ferguson
# rebecca compound ferguson
# ferguson nsubj remain
# remain ccomp reckon
# best acomp remain
# imf compound team
# team nsubj play
# play ccomp remain
# strength dobj play
# longer advmod seri
# seri amod authent
# goe compound authent
# authent nsubj grow
# grow ccomp play
# friendship dobj grow
# feel ccomp reckon
# shea compound whigham
# whigham nsubj greg
# greg compound davi
# tarzan compound davi
# davi nsubj expect
# get aux expect
# expect ccomp feel
# buddi advmod expect
# cop dep buddi
# antic amod lot
# lot dobj expect
# funwith prep expect
# esai nmod charismat
# moral amod charismat
# charismat pobj funwith
# yet advmod reckon
# terrifi compound terrif
# gabriel compound terrif
# pom compound terrif
# klementieff compound terrif
# terrif nsubj word
# henchman appos terrif
# word npadvmod reckon
# franchis det gloriou
# final amod gloriou
# good amod return
# villain nmod return
# bad amod return
# return compound henri
# henri compound czerni
# czerni compound gloriou
# kittridg compound gloriou
# gloriou nsubj remain
# remain ccomp reckon
# gleefulli npadvmod remain
# despic acomp remain
# first amod charact
# appearanceth amod easili
# best amod easili
# new amod easili
# addit compound easili
# easili compound charact
# hayley compound atwel
# atwel compound play
# play compound charact
# type compound charact
# charact nsubj seen
# never neg seen
# seen advcl remain
# film nsubj make
# make ccomp seen
# charact amod everyon
# dynam compound cruis
# cruis compound everyon
# fresh amod comparison
# comparison compound everyon
# everyon nsubj interactchristoph
# who nsubj come
# come relcl everyon
# chemistri amod magnet
# magnet compound instantan
# instantan attr come
# second advmod interactchristoph
# interactchristoph ccomp make
# mcquarri compound sequenc
# direct amod phenomen
# phenomen compound action
# action compound sequenc
# sequenc compound camera
# suitabl compound practic
# practic amod camera
# spend compound million
# million nummod camera
# camera nsubj get
# get ccomp interactchristoph
# close amod possibl
# action compound humanli
# humanli compound possibl
# possibl nsubj remain
# remain ccomp get
# one nummod scale
# best amod scale
# busi compound scale
# work compound scale
# scale attr remain
# there advmod remain
# plenti attr remain
# ca aux angl
# nt neg angl
# angl ccomp make
# nice amod origin
# homag nmod origin
# de nmod palma
# palma compound origin
# origin compound help
# help dobj angl
# give xcomp help
# one nummod mcquarri
# style compound mcquarri
# comparison compound mcquarri
# mcquarri compound film
# previou compound film
# entriesth compound realli
# pace compound realli
# realli compound film
# impress compound film
# film nsubj feel
# feel ccomp give
# like prep feel
# perpetu nmod heist
# third amod act
# act nmod heist
# first compound airport
# airport compound heist
# heist nmod music
# much amod fun
# fun nmod music
# lorn amod balf
# balf compound music
# music pobj like
# yet advmod feel
#
#
#
# Dependency Parsing Tree:
# highlight compound film
# film nsubj know
# know ROOT know
# elev dobj know
# everyth ccomp know
# well intj beat
# realli compound emot
# hammer compound home
# home compound emot
# emot nsubj beat
# beat ccomp know
#
#
#
# Dependency Parsing Tree:
# good advmod feel
# god nsubj feel
# feel ROOT feel
# asham compound approach
# approach compound modicum
# film compound modicum
# modicum compound doubt
# doubt compound tom
# tom nsubj abl
# would aux abl
# still advmod abl
# abl ccomp feel
# deliv compound unbeliev
# unbeliev nmod fallout
# epic amod fallout
# actual amod fallout
# manag nmod fallout
# top amod fallout
# brilliant amod fallout
# fallout dobj abl
# tom compound liter
# liter compound go
# go compound die
# die nsubj keep
# keep ccomp abl
# stunt compound motorbik
# motorbik compound sequenc
# sequenc compound utterli
# utterli ccomp keep
# ludicr compound stake
# intrigu nmod stake
# plot nmod stake
# actual amod stake
# stake nmod support
# familiar amod support
# face nmod support
# abli compound support
# support conj abl
# brilliant amod villain
# new amod villain
# alli compound villain
# villain nsubj set
# set ccomp abl
# part compound ii
# ii compound sensat
# perfectli compound sensat
# sensat dobj set
# final amod mi
# homag nmod mi
# back compound mi
# futur compound mi
# mi nsubj speed
# speed compound pack
# funni compound pack
# action compound pack
# pack nsubj polish
# polish conj abl
# exhilar amod harrison
# harrison dobj polish
# great advmod abl
# last amod week
# week npadvmod abl
# tom npadvmod abl
# still advmod king
# king dep feel
#
#
#
# Dependency Parsing Tree:
# cold advmod open
# open amod interest
# ten nummod way
# grip compound way
# way compound interest
# interest compound cruis
# other amod roll
# credit compound roll
# roll compound cruis
# tom compound cruis
# cruis nsubj topnotch
# still advmod topnotch
# topnotch ROOT topnotch
# ethan compound signatur
# hunt compound signatur
# signatur nsubj run
# run ccomp topnotch
# still advmod excit
# excit ccomp topnotch
# someth amod team
# core compound team
# team dobj excit
# theyr ccomp topnotch
# bare compound screen
# screen compound especi
# especi nsubj ving
# ving advcl theyr
# rhame nsubj disappear
# luther npadvmod disappear
# disappear ccomp topnotch
# final amod landscap
# act compound landscap
# landscap compound util
# beauti compound movi
# movi compound util
# util compound scene
# element compound scene
# action compound scene
# scene compound desert
# mainli compound desert
# desert compound digit
# scene compound premis
# premis compound sentient
# sentient compound digit
# digit compound worldcontrol
# worldcontrol nsubj intrigu
# entiti nsubj intrigu
# intrigu ccomp topnotch
# good amod start
# start nsubj meet
# meet ccomp intrigu
# grace dobj meet
# like prep grace
# hayley compound atwel
# atwel pobj like
# do aux like
# nt neg like
# like ccomp topnotch
# hayley amod grace
# atwel compound grace
# grace compound grace
# grace dobj like
# pretti compound pickpocket
# pickpocket compound key
# key appos grace
# everyth compound ethan
# ethan compound betray
# save compound betray
# betray ccomp like
# leav advcl topnotch
# dead amod repeat
# captur compound repeat
# cycl compound repeat
# repeat dobj leav
# throughout prep repeat
# movi pobj throughout
# make ccomp topnotch
# plot nsubj predict
# predict ccomp make
# bore compound chase
# chase compound scene
# scene nsubj felt
# felt ccomp make
# like prep felt
# bad amod matter
# romant amod matter
# slapstick amod matter
# comedi compound matter
# matter advmod ethan
# much advmod ethan
# ethan pobj like
# save advcl felt
# life dobj save
# risk dobj save
# she nsubj loyal
# never neg loyal
# loyal ccomp felt
# noth compound bind
# bind dobj loyal
# yet advmod loyal
#
#
#
# Dependency Parsing Tree:
# ethan compound train
# deathdefi compound stunt
# stunt compound mountain
# mountain compound train
# land compound train
# train nsubj reflect
# reflect ROOT reflect
# great amod love
# love dobj reflect
# lost acl love
# could aux lose
# lose advcl reflect
# see xcomp lose
# iisa nsubj rebecca
# rebecca ccomp see
# ferguson compound love
# face compound love
# love nsubj lost
# lost advcl lose
# earli compound grace
# imf compound careerand
# careerand compound grace
# grace compound grace
# grace dobj lost
# she nmod grace
# great amod grace
# love compound life
# life compound grace
# grace nsubj caus
# also advmod caus
# caus conj reflect
# iisa compound grace
# death compound gloss
# gloss compound pas
# pas compound grace
# iisa compound sacrif
# sacrif compound grace
# life compound grace
# grace nsubj found
# found conj reflect
# disingenu compound love
# fan compound love
# love nsubj rebecca
# rebecca ccomp found
# ferguson compound charact
# iisa compound charact
# charact nsubj fit
# fit ccomp rebecca
# within prep fit
# mi pobj within
# franchis det grace
# grace nsubj think
# forc compound forgett
# forgett nsubj think
# think ccomp found
# mi nsubj want
# want ccomp think
# grace compound beauti
# mysteri amod beauti
# intrigu compound beauti
# unforgett compound beauti
# beauti nsubj stick
# like prep beauti
# hall compound iren
# berri compound iren
# jinx compound iren
# iren compound atwel
# adler compound atwel
# hayley compound atwel
# atwel nsubj stick
# could aux stick
# stick ccomp want
# land compound nail
# nail compound film
# tom compound date
# cruis compound date
# date compound film
# film compound date
# guess compound date
# pay compound date
# date compound bos
# bos dobj stick
# other amod thing
# thing nsubj fail
# fail ccomp want
# dead advmod fail
# reckon xcomp fail
# villain compound henchman
# gabriel compound henchman
# henchman dobj reckon
# pari nmod impact
# gener compound signific
# memor compound signific
# signific nmod impact
# impact nmod derail
# final amod derail
# neverend compound derail
# train compound derail
# derail nsubj made
# almost advmod made
# made conj reflect
# exit compound theater
# theater compound mi
# mi nsubj favorit
# least advmod favorit
# favorit ccomp made
# franchis det mi
# ill amod catch
# catch compound mi
# mi dobj favorit
# dead intj reflect
# reckon conj reflect
# part dobj reckon
# home advmod part
# paramountplu amod stream
# stream compound cost
# cost npadvmod reckon
#
#
#
# Dependency Parsing Tree:
# read ROOT read
# good amod review
# review nsubj feel
# feel ccomp read
# like mark m
# i nsubj m
# m advcl feel
# gaslit amod script
# stem compound script
# script attr m
# taught conj read
# classroom dobj taught
# write conj read
# everyth compound laugh
# simpli compound laugh
# work nmod laugh
# bad amod laugh
# laugh dobj write
# loud amod time
# mani compound time
# time npadvmod write
# tri amod actor
# seriou nmod actor
# incred amod actor
# stilt compound actor
# actor nsubj look
# do aux look
# nt neg look
# look conj read
# like prep look
# even advmod line
# believ compound line
# line nsubj put
# put compound movi
# mouth compound compar
# compar compound previou
# previou compound movi
# movi nsubj feel
# does aux feel
# nt neg feel
# even advmod feel
# feel conj read
# like prep feel
# mi pobj like
# franchis det film
# film nsubj nonsens
# nonsens ccomp feel
# constantli compound woman
# ramp compound stake
# stake compound b
# b compound woman
# crap compound woman
# woman dobj nonsens
# written acl woman
# way npadvmod written
# act compound spell
# undermin compound spell
# spell compound alreadi
# someth compound audienc
# audienc compound alreadi
# alreadi nsubj know
# know conj read
# whoever nsubj work
# wrote aux work
# never neg work
# work csubj pay
# whoever dobj end
# greenlit amod someon
# similarli compound someon
# shunt compound someon
# someon nsubj project
# better advmod project
# project compound mindthi
# mindthi nsubj end
# could aux end
# well advmod end
# end ccomp work
# franchis det half
# know amod half
# hour compound half
# half dobj end
# want prep work
# check compound see
# phone compound see
# see nsubj go
# much advmod longer
# longer advmod go
# go ccomp want
# would aux pay
# pay ccomp know
# watch compound sequel
# sequel compound arc
# noth compound interest
# interest compound plot
# plot compound arc
# arc dobj pay
# came conj pay
# fruition dobj pay
# were aux get
# nt neg were
# descent compound look
# action compound sequenc
# sequenc compound look
# look nsubj get
# would aux get
# star compound film
# film nsubj get
# get advcl read
# posit compound rate
# rate compound ill
# ill acomp get
# never neg know
# know parataxis get
# especi nmod previou
# peopl compound presum
# presum nmod previou
# consum compound previou
# previou compound demonstr
# instal amod demonstr
# demonstr nmod baffl
# better advmod everi
# everi amod baffl
# singl amod baffl
# respect compound baffl
# baffl dobj know
#
#
#
# Dependency Parsing Tree:
# latest amod movi
# mission compound imposs
# imposs compound movi
# movi compound dunk
# slam compound dunk
# dunk compound need
# need nsubj seen
# seen ROOT seen
# biggest amod screen
# screen compound possibl
# possibl compound certainli
# tom compound cruis
# cruis compound certainli
# certainli nsubj know
# know ccomp seen
# make xcomp know
# movi nsubj univers
# anoth advmod movi
# univers compound cruse
# cruse ccomp make
# could aux iron
# iron nsubj felt
# man compound alway
# alway advmod iron
# felt conj seen
# aggress compound mission
# mission compound imposs
# imposs dobj felt
# franchis det way
# way npadvmod felt
# make advcl seen
# that det movi
# probabl amod movi
# dialog compound movi
# movi nsubj felt
# felt ccomp make
# like prep felt
# ethan pobj like
# hawk compound someth
# captain compound someth
# america compound someth
# someth nsubj go
# go ccomp felt
# bonafed amod system
# supervillain compound form
# form compound system
# system dobj go
# far advmod go
# i nsubj m
# m advcl go
# concern nmod villain
# best amod villain
# villain nmod snice
# franchis det snice
# snice attr m
# late advmod great
# great amod assembl
# phillip nmod aveng
# seymour amod aveng
# huffmanth compound aveng
# aveng compound assembl
# assembl attr m
# franchis det rhime
# regular amod ving
# simon compound dunn
# pegg compound dunn
# dunn compound ving
# ving compound rhime
# rhime nsubj say
# say conj seen
# glee nsubj start
# start ccomp say
# franchis det cruse
# cruse dobj start
# luther nsubj make
# make ccomp say
# return ccomp make
# imf compound agent
# agent compound ferguson
# rebecca compound ferguson
# ferguson compound role
# repris compound role
# role dobj seen
# last amod movi
# movi compound haley
# haley nsubj atwel
# atwel conj seen
# movi dobj atwel
# well intj make
# none nsubj make
# make ccomp seen
# happi nsubj ving
# ving ccomp make
# still advmod ving
# franchiseth compound action
# action nsubj sequenc
# sequenc nsubj stay
# good amod pictur
# pictur dobj sequenc
# worth amod sequenc
# stay ccomp make
# seat dobj stay
# almost advmod three
# three nummod hour
# hour npadvmod stay
# add ccomp make
# littl compound action
# action dobj add
# inbetween amod hero
# hero compound dialogueand
# journey compound dialogueand
# dialogueand ccomp add
# part dobj dialogueand
# one nummod part
# part npadvmod fill
# two nummod fill
# big amod fill
# shoe compound fill
# fill conj seen
#
#
#
# Dependency Parsing Tree:
# major amod spoiler
# spoiler compound imposs
# minor amod reviewth
# plot compound exposit
# exposit compound reviewth
# reviewth compound imposs
# mission compound imposs
# imposs nsubj make
# franchis det essenti
# essenti appos imposs
# reboot prep imposs
# j compound abram
# j compound abram
# abram compound step
# step pobj reboot
# make ROOT make
# mi nsubj saw
# saw ccomp make
# critic compound flaw
# flaw nmod team
# ...
# nt neg mention
# mention ccomp think
# key punct imag
#
#
#
# Dependency Parsing Tree:
# oh amod brother
# brother ROOT brother
#
#
#
# Dependency Parsing Tree:
# matter advmod say
# peopl nsubj say
# say ROOT say
# review compound film
# film nsubj need
# best advmod film
# one nummod realli
# franchisedid amod realli
# realli nsubj need
# need ccomp say
# anoth amod mission
# mission compound fun
# film compound fun
# realli compound fun
# fun nsubj watch
# watch ccomp need
# thoughso amod settl
# settl compound film
# watch compound film
# film nsubj came
# came ccomp say
# away advmod came
# watch advcl came
# movi compound thought
# thrill compound thought
# thought advcl came
# would aux was
# beth compound guy
# main amod guy
# bad amod guy
# guy nsubj was
# was ccomp thought
# nt neg was
# much advmod one
# one nummod harri
# back amod harri
# harri attr was
# last amod way
# one nummod way
# least advmod bad
# bad amod way
# guy compound alley
# ball compound alley
# himth compound alley
# alley compound way
# way npadvmod fight
# fight advcl came
# scene dobj fight
# aw intj film
# done amod heck
# heck nsubj film
# could aux film
# film ccomp say
# better advmod fight
# fight compound dread
# scene compound dread
# ferguson compound dread
# sword compound dread
# fight compound dread
# scene compound dread
# dread nsubj suit
# did aux suit
# nt neg suit
# suit ccomp film
# style dobj suit
# moviethen nmod movi
# weak amod charact
# storylin compound charact
# charact compound movi
# movi npadvmod film
# one nummod dimension
# dimension nsubj help
# did aux help
# nt neg help
# help ccomp say
# film xcomp help
# runtimeth amod bike
# bike compound jump
# jump compound week
# internet compound week
# week npadvmod film
# made xcomp help
# scene nsubj watch
# watch ccomp made
# film dobj watch
#
#
#
# Dependency Parsing Tree:
# oh intj bring
# seen amod alreadi
# alreadi nsubj bring
# did aux bring
# nt neg bring
# bring ROOT bring
# much amod thrill
# thrill dobj bring
# haveov nsubj disappoint
# disappoint relcl thrill
# movi dobj disappoint
# franchis compound watch
# watch dep bring
# next amod fan
# one nummod fan
# ye compound fan
# fan compound filmscruis
# filmscruis compound recent
# recent nsubj said
# said conj bring
# may aux keep
# keep ccomp said
# make xcomp keep
# well advmod make
# go xcomp make
# turn xcomp keep
# like prep turn
# one pobj like
# do dep bring
# nt neg bring
#
#
#
# Dependency Parsing Tree:
# huge amod fan
# fan compound mi
# mi nsubj pull
# franchis det part
# best amod part
# part nmod plan
# mi appos part
# movi compound plan
# plan nsubj pull
# pull ROOT pull
# imposs amod mission
# mission compound thu
# thu nsubj quit
# quit ccomp pull
# disappoint compound mission
# mission dobj quit
# never neg seem
# seem conj pull
# difficult oprd seem
# let dep pull
# alon nsubj impossibleact
# impossibleact ccomp let
# okay amod chase
# car compound chase
# chase compound cliff
# funni compound cliff
# excit compound cliff
# jump compound cliff
# cliff nsubj seem
# seem conj pull
# forc nsubj keep
# would aux keep
# keep ccomp seem
# drive amod uphil
# uphil nsubj take
# take xcomp keep
# short amod cut
# cut nsubj reach
# reach compound train
# train dobj keep
# was conj pull
# nt neg was
# even advmod was
# fast amod train
# train compound key
# key nsubj kept
# kept conj pull
# stolen amod pocket
# pocket dobj kept
# mani compound time
# time npadvmod kept
# make xcomp kept
# wonder compound script
# lazi compound script
# script nsubj kill
# kill ccomp make
# old amod gf
# gf dobj kill
# make dep pull
# new amod gf
# gf ccomp make
# also advmod make
# lazi compound mi
# writingunlik compound mi
# mi compound ethan
# ethan nummod plan
# singl amod plan
# smart amod plan
# move compound plan
# plan nsubj felt
# felt ccomp make
# like intj let
# let advcl felt
# go nsubj see
# see ccomp let
# happensam dobj see
# sure advmod gave
# mi compound ignor
# fan compound ignor
# ignor nsubj gave
# weak amod ignor
# gave ccomp see
# film compound rate
# rate dobj gave
#
#
#
# Dependency Parsing Tree:
# instal amod stunt
# franchis det entertain
# wellmad compound highli
# highli nsubj entertain
# entertain nmod stunt
# decent amod fun
# fun dobj entertain
# alway advmod entertain
# tri amod stunt
# invent nmod stunt
# better amod stunt
# stunt nsubj noth
# also advmod noth
# noth ROOT noth
# wrong amod cinemat
# cinemat compound definit
# direct amod excel
# excel compound definit
# definit nmod money
# worth amod money
# money nsubj feel
# still advmod feel
# feel ccomp noth
# like prep feel
# lack pobj like
# someth amod soul
# miss compound soul
# soul appos lack
# moviepartli nsubj think
# think compound harley
# act compound harley
# tom compound harley
# harley nsubj feel
# amaz advmod harley
# everyth compound rest
# rest pobj amaz
# feel ccomp feel
# like prep feel
# partli pobj like
# end parataxis feel
# like prep end
# cherri compound top
# top compound movi
# cliffhang compound movi
# movi nsubj end
# sort advmod end
# end conj feel
# anoth amod thing
# thing nsubj bother
# bother ccomp end
# chase compound scene
# scene compound event
# adrenalin compound induc
# induc compound event
# event dobj bother
# entertain conj noth
#
#
#
# Dependency Parsing Tree:
# ye ROOT ye
#
#
#
# Dependency Parsing Tree:
# oh intj deliv
# boy compound deliv
# deliv nsubj feel
# also advmod feel
# feel ROOT feel
# like prep feel
# purpos pobj like
# almost advmod like
# like prep feel
# watch pobj like
# fastfuri compound crazi
# le compound crazi
# crazi dobj watch
# better compound highli
# actedi compound highli
# highli nsubj recommend
# recommend conj feel
# movi dobj recommend
# like prep recommend
# previou pobj like
# instal amod love
# love appos previou
# one nummod action
# action appos previou
# insan amod time
# good amod time
# time compound howev
# howev compound movi
# movi compound time
# time nsubj end
# end ccomp recommend
# franchis det peopl
# clearli amod peopl
# peopl nsubj involv
# involv compound start
# start nsubj get
# get ccomp end
# bore nmod movi
# good amod movi
# entertain compound movi
# movi nmod soulless
# hollow amod soulless
# soulless nsubj was
# was ccomp get
# nt neg was
# coupl compound scene
# action compound scene
# scene nsubj rememb
# would aux rememb
# rememb conj feel
# singl amod day
# thing compound movi
# movi compound coupl
# coupl compound day
# day dobj rememb
#
#
#
# Dependency Parsing Tree:
# watch ROOT watch
# greatest amod cinema
# carchas compound cinema
# histori compound cinema
# cinema dobj watch
# still advmod was
# was ccomp watch
# nt neg was
# even advmod best
# best advmod was
# scene compound fantast
# movieaft compound fantast
# fantast nsubj underwat
# underwat ccomp was
# open amod introduct
# introduct nmod film
# next amod film
# imposs amod mission
# mission compound film
# rest compound film
# film nsubj essenti
# essenti ccomp underwat
# huge amod setpiec
# action compound setpiec
# setpiec nsubj get
# like prep setpiec
# noth pobj like
# ever advmod noth
# experienc compound screen
# screen appos noth
# beforeeveryth advmod get
# get ccomp essenti
# exponenti amod pas
# epic amod time
# time compound pas
# pas nsubj think
# think ccomp get
# sure amod el
# peak compound el
# someth compound el
# el nsubj come
# come compound crash
# crash nsubj go
# onto prep crash
# screen compound stake
# stake compound rise
# rise pobj onto
# even advmod higher
# higher advmod rise
# go ccomp think
# againth amod pace
# pace nsubj quit
# quit ccomp go
# uniqu dobj quit
# feel advcl go
# like mark work
# sequenc compound shortfilm
# thrill compound shortfilm
# shortfilm nsubj work
# still advmod work
# work advcl feel
# whole amod moment
# narr amod momentum
# awesom compound momentum
# momentum compound pul
# pul nmod moment
# everi amod moment
# moment dobj work
# ca aux imagin
# nt neg imagin
# imagin advcl work
# top amod part
# part dobj imagin
# can aux wait
# not neg wait
# wait ccomp watch
# find xcomp wait
# outep compound movement
# movement compound stunt
# ambit compound stunt
# stunt nmod humour
# humour nmod bravado
# brilliant amod bravado
# new amod charact
# charact nmod bravado
# sheer amod bravado
# bravado dobj find
# behind prep bravado
# camera pobj behind
# ever advmod find
# film nmod moment
# practic amod pandem
# pandem appos film
# obvious amod screen
# watch npadvmod biggest
# biggest amod screen
# cinema compound screen
# screen appos film
# possibl compound moment
# moment compound train
# train nsubj enter
# enter nsubj say
# tunnel compound liter
# liter compound fault
# breathtakingif compound fault
# look compound fault
# fault dobj enter
# would aux say
# say ccomp find
# exposit compound scene
# scene compound bit
# drag compound bit
# bit nsubj felt
# almost advmod felt
# felt ccomp say
# like prep felt
# repeat pobj like
# even advmod complain
# ca aux complain
# nt neg complain
# complain advcl felt
# stylishli amod film
# film dobj complain
# ever advmod franchisejust
# franchisejust npadvmod let
# let ccomp watch
# cruis amod mcquarri
# mcquarri nsubj produc
# produc compound film
# everi amod film
# action compound film
# film nsubj made
# made ccomp let
# nobodi compound level
# el compound level
# remot compound level
# close amod level
# level nsubj watch
# would aux watch
# gladli nsubj watch
# watch ccomp made
# immedi compound book
# book compound ticket
# ticket compound right
# right dobj watch
#
#
#
# Dependency Parsing Tree:
# want ROOT want
# write compound larh
# larh compound review
# review nsubj make
# make ccomp want
# mani compound detail
# detail nsubj thought
# thought ccomp make
# aw intj nopelet
# movi compound deserv
# deserv npadvmod aw
# nopelet nmod word
# short amod fulfil
# fulfil compound amount
# amount compound word
# word nsubj say
# say ccomp thought
# main amod gist
# gist nsubj want
# want ccomp say
# humor compound movi
# movi dobj want
#
#
#
# Dependency Parsing Tree:
# aw det repetit
# repetit nsubj saw
# saw ROOT saw
# previou compound part
# part nsubj bother
# bother ccomp saw
# depth amod charact
# charact compound demis
# onedimension compound demis
# shallow amod hero
# sympathi compound hero
# hero compound demis
# demis nsubj make
# make ccomp saw
# u compound vapid
# vapid nsubj indiffer
# indiffer ccomp make
# plot compound control
# whole amod idea
# idea compound control
# joke compound control
# control dobj indiffer
# even advmod first
# first amod cruis
# part nmod sen
# drag nmod sen
# forev amod sen
# sen nmod part
# part nmod cruis
# huge amod cruis
# wast compound timetom
# timetom amod cruis
# cruis nsubj stop
# must aux stop
# stop ccomp make
# ever advmod stop
# piti dep stop
# part nsubj make
# make ccomp piti
# whole amod couldv
# franchis det couldv
# sour amod couldv
# spoil compound dissapoint
# dissapoint compound couldv
# couldv ccomp make
# great amod couldv
# nopebland cc stop
# silli conj saw
#
#
#
# Dependency Parsing Tree:
# straight advmod dead
# dead nsubj reckon
# reckon nsubj think
# part compound fine
# fine nsubj think
# think ROOT think
# weakest advmod put
# last amod instalmentsi
# four nummod instalmentsi
# instalmentsi nsubj put
# ca aux put
# nt neg put
# put ccomp think
# finger dative put
# one nummod thing
# exact amod thing
# thing nsubj felt
# felt conj think
# littl compound compar
# underdon compound compar
# compar dobj felt
# last amod mi
# mi npadvmod expect
# expect advcl felt
# big amod thing
# thing nmod movi
# whole amod movi
# movi nsubj felt
# combin compound thing
# thing nsubj felt
# like prep thing
# act pobj like
# felt ccomp expect
# littl compound script
# weak amod script
# guess compound script
# script nmod action
# fine amod action
# action dobj felt
# decent amod compar
# great amod compar
# compar appos action
#
#
#
# Dependency Parsing Tree:
# mi dep use
# like prep use
# john compound wick
# wick pobj like
# i nsubj use
# m aux use
# use nsubj especi
# plot compound noth
# noth compound alway
# new compound alway
# alway dobj use
# still advmod interest
# interest ccomp use
# especi nsubj got
# time dobj especi
# real amod advanc
# world compound advanc
# advanc nsubj seem
# seem advcl especi
# heat nmod pickpocket
# whole amod pickpocket
# pickpocket nmod hour
# key amod hour
# hour nsubj especi
# also advmod got
# got ROOT got
# bore advmod fast
# fast amod clich
# mani compound clich
# clich nsubj start
# start compound combat
# pile compound hand
# hand compound hand
# hand compound combat
# combat compound stuff
# weakest amod stuff
# stuff dobj got
# i nsubj seen
# ve aux seen
# seen relcl stuff
# especi ccomp seen
# venic amod scene
# bridg compound scene
# scene dobj especi
# look conj got
# aw intj look
# like intj see
# could aux see
# see advcl look
# choreographi amod storm
# best amod storm
# scene compound storm
# desert compound storm
# storm nsubj start
# start ccomp see
# realli compound attent
# attent dobj start
# everyth nsubj seem
# seem conj got
# averagei nsubj know
# do aux know
# nt neg know
# know ccomp seem
# everyon compound someon
# el compound someon
# complet compound trick
# trick compound someon
# someon nsubj go
# go ccomp know
# someon compound mask
# el compound mask
# mask compound stage
# bore compound stage
# stage dobj go
#
#
#
# Dependency Parsing Tree:
# i nsubj mean
# m appos i
# kinda advmod roll
# roll compound hope
# eye compound realli
# realli compound hope
# hope compound fuse
# machin compound fuse
# blow compound fuse
# fuse appos i
# mean nsubj seen
# seen ccomp see
# last amod stunt
# themtom amod cruis
# cruis compound stunt
# awesom compound stunt
# stunt compound wish
# alway amod respect
# respect compound thing
# thing compound wish
# realli compound wish
# wish nsubj show
# did aux show
# nt neg show
# show ccomp seen
# motorbik compound cliff
# cliff compound jump
# jump compound trailer
# scene compound trailer
# trailer nsubj see
# see compound stunt
# trailer compound liter
# liter nmod stunt
# whole amod stunt
# stunt nsubj get
# do aux get
# nt neg get
# get ccomp show
# wrong amod impress
# truli compound impress
# impress nsubj show
# show ccomp seen
# whole amod complet
# thing compound complet
# complet nsubj kill
# kill ccomp show
# meim compound bum
# slightli compound bum
# bum dobj kill
# one nsubj come
# come aux see
# see ROOT see
# indian amod watch
# jone compound lot
# lot compound watch
# fun compound watch
# watch nsubj care
# do aux care
# nt neg care
# care ccomp see
# runtim amod suck
# suck dobj care
# whole amod time
# time npadvmod care
# felt ccomp see
# timepeopl compound movi
# love compound movi
# movi compound mi
# mi nsubj fizzl
# may aux fizzl
# fizzl ccomp felt
# bit dobj fizzl
# one npadvmod fizzl
#
#
#
# Dependency Parsing Tree:
# mission compound imposs
# imposs nsubj reckon
# dead amod imposs
# reckon ROOT reckon
# part dobj reckon
# mi nsubj anoth
# anoth ccomp reckon
# strong amod cruis
# entri amod cruis
# actionspi nmod cruis
# seri compound cruis
# ethan compound cruis
# cruis nsubj look
# look conj reckon
# slightli amod determin
# older amod determin
# le compound determin
# determin attr look
# save conj reckon
# world compound film
# believ compound film
# sequel compound film
# film dobj save
# last amod outing
# outing nsubj see
# well advmod see
# see conj reckon
# time dobj see
# there expl skynetlik
# skynetlik ccomp see
# sentientai dobj skynetlik
# that mark get
# manipul compound nefari
# nefari compound type
# type compound take
# take compound team
# world compound team
# imf compound team
# team nsubj get
# get ccomp skynetlik
# two nummod halv
# halv compound luther
# key amod stop
# stop nmod ferguson
# itisla amod ferguson
# ferguson compound luther
# benji compound luther
# pegg compound luther
# luther nsubj rhame
# rhame conj reckon
# back advmod rhame
#
#
#
# Dependency Parsing Tree:
# well advmod keep
# cia compound bos
# bos compound kittridg
# kittridg compound czerni
# czerni compound thief
# grace compound atwel
# atwel compound thief
# thief compound guy
# newcom nmod guy
# bad amod guy
# guy nsubj keep
# keep ROOT keep
# thwart compound gabriel
# gabriel oprd keep
# moral amod ethan
# ethan npadvmod keep
# past oprd keep
# pari compound mcquarri
# klementieff compound consist
# consist compound mcquarri
# mcquarri compound director
# director pobj past
# two nummod film
# previou compound film
# film appos director
# help oprd keep
# everyth nsubj feel
# feel ccomp help
# assur compound realli
# work compound realli
# realli dobj feel
# solid amod falloutther
# followup compound falloutther
# falloutther nsubj run
# funni compound moment
# moment compound sincer
# sincer appos falloutther
# one nummod ethan
# ethan appos falloutther
# run conj keep
# contractuallyoblig nmod train
# whole amod train
# final amod train
# scene compound train
# train dobj run
# excel oprd keep
# mani compound thing
# thing nsubj happen
# happen ccomp excel
# there advmod happen
# plenti advcl happen
# good amod setpiec
# setpiec dobj plenti
# throughout prep setpiec
# includ amod chase
# good amod chase
# car compound chase
# chase compound piecederesist
# howev compound piecederesist
# piecederesist compound jump
# motorbik compound base
# cliff compound base
# base compound jump
# jump pobj throughout
# someth nmod fact
# el compound fact
# fact appos jump
# cruis compound inspir
# real amod multipl
# multipl compound inspir
# time compound inspir
# crazi compound inspir
# inspir oprd keep
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Name: Clean_Review, Length: 1000, dtype: object

# %%
from collections import Counter
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import spacy
import pandas as pd
from collections import Counter

nlp = spacy.load("en_core_web_sm")

reviews_data = pd.read_csv('/content/drive/MyDrive/imdb_reviews_dataset.csv')

def ner_extraction(review):
    doc = nlp(review)
    person_names = Counter()
    organizations = Counter()
    locations = Counter()
    product_names = Counter()
    dates = Counter()
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            person_names[ent.text] += 1
        elif ent.label_ == 'ORG':
            organizations[ent.text] += 1
        elif ent.label_ == 'GPE':
            locations[ent.text] += 1
        elif ent.label_ == 'PRODUCT':
            product_names[ent.text] += 1
        elif ent.label_ == 'DATE':
            dates[ent.text] += 1
    return person_names, organizations, locations, product_names, dates

ner_results = reviews_data['Clean_Review'].apply(ner_extraction)

person_names_total = Counter()
organizations_total = Counter()
locations_total = Counter()
product_names_total = Counter()
dates_total = Counter()

for person_names, organizations, locations, product_names, dates in ner_results:
    person_names_total += person_names
    organizations_total += organizations
    locations_total += locations
    product_names_total += product_names
    dates_total += dates

print("Total Sum of Each Entity Type:")
print("Person Names:", sum(person_names_total.values()))
print("Organizations:", sum(organizations_total.values()))
print("Locations:", sum(locations_total.values()))
print("Product Names:", sum(product_names_total.values()))
print("Dates:", sum(dates_total.values()))
# Out:
# Total Sum of Each Entity Type:
# Person Names: 3640
# Organizations: 960
# Locations: 360
# Product Names: 0
# Dates: 360

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
'''Question 2 was good enough to execute, but 1 & 3 were very time
consuming and difficult to crack. Time given to finish this
assignment was okay compared to the time usually given fpr exeercises.'''
# Out:
# 'Question 2 was good enough to execute, but 1 & 3 were very time \nconsuming and difficult to crack. Time given to finish this \nassignment was okay compared to the time usually given fpr exeercises.'
